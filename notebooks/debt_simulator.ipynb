# %% [markdown]
# # Modelagem de Horizonte de Investimentos com Contraimento de Dívidas

# %% [markdown]
# ## Bibliotecas:

# %%
import matplotlib.pyplot as plt
import scr.equity as eq
import scr.vis as vis
import scr.loan as loan

# %% [markdown]
# ## *Patrimônio*, após *t* meses, sem compras (puro):

# %% [markdown]
# ### Parâmetros:

# %% [markdown]
# Patrimônio em t=0:                          P0
#
# Aporte mensal a partir de t=0:              Am
#
# Horizonte de tempo da simulação (em meses): Th
#
# Rendimento mensal médio:                    rm
#
# Aumento de aporte mensal médio:             mm

# %% [markdown]
# #### Cálculo de *Rendimento* e *Aumento de Aporte* **Mensais** a partir de quantidades **Anuais** :

# %% [markdown]
# É mais fácil de imaginar o **rendimento do seu patrimônio na escala de Anos**, ao invés de meses. Muitas métricas são divulgadas assim, também, como **taxa Selic ou juros Pré-fixado de títulos**, por exemplo.
#
# Também, o aumento de *aporte* é, de modo realista, feito **anualmente**. **Não é conveniente** e, às vezes, **nem possível**, aumentar seu *aporte* por três ou quatro reais ao mês. Mas, aumentar o *aporte* por 50 reais por ano é **realista, possível e satisfatório**. Sem falar que esse pequeno detalhe **aumenta em milhares de reais o patrimônio** ao longo do tempo.

# %% [markdown]
# ##### Parâmetros anuais:

# %%
r = 1.10 #rendimento anual médio dos investimentos

m = 1.05 #Aumento anual do aporte mensal

# %% [markdown]
# ##### Função de Conversão:

# %%
eq.anual_para_mensal(taxa_anual=r)
# Out:
# 1.0079741404289038

# %% [markdown]
# ### Função:

# %% [markdown]
# #### Função auxiliar (patrimônio total acumulado do investimento mensal dos aportes):

# %%
eq._patrimonio_acumulado_de_aportes(aporte_mensal=                           1000,
                                    rendimento_mensal=    eq.anual_para_mensal(r),
                                    aumento_aporte_mensal=eq.anual_para_mensal(m),
                                    meses=                                   12*3)
# Out:
# 45967.0533929435

# %% [markdown]
# #### Patrimônio Puro:

# %%
eq.patrimonio_puro(patrimonio_inicial=                      1000,
                   aporte_mensal=                           1000,
                   rendimento_mensal=    eq.anual_para_mensal(r),
                   aumento_aporte_mensal=eq.anual_para_mensal(m),
                   meses=                                   12*3)
# Out:
# 47298.0533929435

# %% [markdown]
# ### Teste:

# %% [markdown]
# #### Exemplo de Parâmetros:

# %%
P0_exemplo = 40000.00                   #Patrimônio em t=0: P0 em reais; float

Am_exemplo = 270.00                     #Aporte mensal a partir de t=0: Am em reais; float

Th_exemplo = 120                        #Horizonte de tempo da simulação (em meses): Th em meses; int

rm_exemplo = eq.anual_para_mensal(r)    #Rendimento mensal médio: rm em decimal; float

mm_exemplo = eq.anual_para_mensal(m)    #Aumento de aporte mensal médio: mm em decimal; float

# %% [markdown]
# #### Patrimônio após Th:

# %%
eq.patrimonio_puro(P0_exemplo, 
                   Am_exemplo, 
                   rm_exemplo, 
                   mm_exemplo, 
                   Th_exemplo)
# Out:
# 171519.02019712687

# %% [markdown]
# #### Visualização:

# %% [markdown]
# ##### Definição de função de patrimônio por tempo:

# %%
eq.patrimonio_puro_por_tempo(P0_exemplo, 
                             Am_exemplo, 
                             rm_exemplo, 
                             mm_exemplo, 
                             Th_exemplo)
# Out:
# [40270.0,
#  40862.21864849353,
#  41460.264226667205,
#  42064.187699125934,
#  42674.04045520657,
#  43289.87431243925,
#  43911.74152003715,
#  44539.69476241384,
#  45173.78716272941,
#  45814.072286464856,
#  46460.60414502561,
#  47113.43719937377,
#  47772.62636368991,
#  48438.2270090642,
#  49110.294967217305,
#  49788.886534251404,
#  50474.05847443131,
#  51165.868023995994,
#  51864.37289500104,
#  52569.63127919192,
#  53281.70185190843,
#  54000.64377602068,
#  54726.51670589682,
#  55459.380791402626,
#  56199.29668193332,
#  56946.32553047798,
#  57700.528997716574,
#  58461.96925615007,
#  59230.708994263725,
#  60006.81142072403,
#  60790.34026860933,
#  61581.359799674625,
#  62379.93480865065,
#  63186.130627577564,
#  64000.013130173626,
#  64821.64873623896,
#  65651.1044160948,
#  66488.44769505852,
#  67333.74665795467,
#  68187.06995366229,
#  69048.48679969888,
#  69918.0669868413,
#  70795.88088378387,
#  71681.9994418338,
#  72576.49419964469,
#  73479.4372879879,
#  74390.90143456246,
#  75310.9599688437,
#  76239.68682697082,
#  77177.15655667377,
#  78123.4443222399,
#  79078.62590952056,
#  80042.77773097795,
#  81015.97683077256,
#  81998.30088989154,
#  82989.82823131846,
#  83990.63782524456,
#  85000.80929432185,
#  86020.42291895875,
#  87049.55964265802,
#  88088.3010773978,
#  89136.729509056,
#  90194.92790287812,
#  91262.97990898929,
#  92340.96986795044,
#  93428.9828163593,
#  94527.10449249645,
#  95635.42134201668,
#  96754.0205236862,
#  97882.98991516599,
#  99022.41811884167,
#  100172.39446770023,
#  101333.00903125395,
#  102504.3526215122,
#  103686.51679900089,
#  104879.59387883072,
#  106083.67693681389,
#  107298.85981563019,
#  108525.23713104264,
#  109762.90427816304,
#  111011.95743776785,
#  112272.49358266513,
#  113544.61048411226,
#  114828.40671828549,
#  116123.98167280157,
#  117431.43555329155,
#  118750.86939002771,
#  120082.38504460343,
#  121426.08521666712,
#  122782.07345070996,
#  124150.45414290833,
#  125531.33254802128,
#  126924.81478634337,
#  128331.00785071334,
#  129750.01961357924,
#  131181.95883412004,
#  132626.935165425,
#  134085.05916173026,
#  135556.44228571354,
#  137041.1969158479,
#  138539.43635381426,
#  140051.27483197348,
#  141576.8275208986,
#  143116.21053696744,
#  144669.54095001635,
#  146236.93679105543,
#  147818.51706004565,
#  149414.40173373837,
#  151024.71177357802,
#  152649.5691336683,
#  154289.0967688021,
#  155943.41864255603,
#  157612.65973545017,
#  159296.94605317304,
#  160996.40463487292,
#  162711.16356151542,
#  164441.3519643086,
#  166187.10003319534,
#  167948.5390254142,
#  169725.80127412884,
#  171519.02019712687]

# %% [markdown]
# ##### Definição de função de visualização de patrimônio por tempo:

# %%
vis.plotar_patrimonio_por_tempo(P0_exemplo, 
                               Am_exemplo, 
                               rm_exemplo, 
                               mm_exemplo, 
                               Th_exemplo)

# %% [markdown]
# #### Motivação para aumento de aporte anualmente (mesmo que pouco):

# %%
# plotar comparação com e sem aumento de aporte mensal
vis.plotar_comparacao(P0_exemplo, 
                      Am_exemplo, 
                      rm_exemplo, 
                      mm_exemplo, 
                      Th_exemplo)

# %%
print(f"Patrimônio final com aumento: {eq.patrimonio_puro(P0_exemplo, 
                                                          Am_exemplo, 
                                                          rm_exemplo, 
                                                          mm_exemplo, 
                                                          Th_exemplo):.2f}") #aumento de 5% ao ano no aporte mensal

print(f"Patrimônio final sem aumento: {eq.patrimonio_puro(P0_exemplo, 
                                                          Am_exemplo, 
                                                          rm_exemplo, 
                                                          1.0, 
                                                          Th_exemplo):.2f}") #sem aumento no aporte mensal (aumento de 0% ao ano, ou seja, aporte mensal constante)

print(f"Vantagem do aumento em {Th_exemplo/12} anos: {eq.patrimonio_puro(P0_exemplo, 
                                                            Am_exemplo, 
                                                            rm_exemplo, 
                                                            mm_exemplo, 
                                                            Th_exemplo) - eq.patrimonio_puro(P0_exemplo, 
                                                                                             Am_exemplo, 
                                                                                             rm_exemplo, 
                                                                                             1.0, 
                                                                                             Th_exemplo):.2f}")

print(f"Valor do aporte no último mês: {Am_exemplo * (mm_exemplo ** Th_exemplo):.2f}")

vis.plotar_comparacao(P0_exemplo, 
                      Am_exemplo, 
                      rm_exemplo, 
                      mm_exemplo, 
                      Th_exemplo)
# Out:
# Patrimônio final com aumento: 171519.02
# Patrimônio final sem aumento: 158413.25
# Vantagem do aumento em 10.0 anos: 13105.77
# Valor do aporte no último mês: 439.80

# %% [markdown]
# ## Empréstimo Básico:

# %% [markdown]
# ### Parâmetros:

# %% [markdown]
# Valor do Bem **à vista**: Vv
#
# Entrada do Empréstimo:    E
#
# Número de parcelas:       np
#
# Juros efetivo mensal:     Jm
#
# Valor da parcela:         Vp

# %% [markdown]
# #### Cálculo do *número de parcelas* a partir do *valor da parcela* **desejado**:

# %% [markdown]
# *Valor do Bem* é fixo.
#
# *Entrada*, normalmente, tem um valor mínimo, mas além desse valor é escolha do cliente.
#
# *Juros efetivo mensal* é escolha do agiota.
#
# Aqui o cliente pode escolher o *valor da parcela*.
#
# O *número de parcelas* necessárias para quitar o empréstimo do Bem é, então, calculado.

# %% [markdown]
# ##### Função do *Valor da Parcela*, **escolhendo** *número de prestações*:

# %%
loan.valor_parcela(50000,      #valor_vista_do_bem
                   10000,#valor_entrada_emprestimo
                   1.01,       #1% ao mês de juros
                   36)         #número de parcelas
# Out:
# 1328.5723925140478

# %% [markdown]
# ##### Função Comparativa entre o *Valor da Parcela* e o *número de prestações*, para vários *números de prestações*.
#
# OBS: se o *número de parcelas* é zero, então o Bem foi pago **à vista**, então a **parcela zero** é só resto do pagamento depois da *entrada* hipotética.

# %%
loan.tabela_comparativa(50000,#      valor_vista_do_bem
                        10000,#valor_entrada_emprestimo
                        juros_mensais=            1.01)
# Out:
# [(0, 40000),
#  (1, 40400.0),
#  (2, 20300.49751243777),
#  (3, 13600.88445925877),
#  (4, 10251.243756466409),
#  (5, 8241.591984635203),
#  (6, 6901.934668435259),
#  (7, 5945.131316564664),
#  (8, 5227.611681732615),
#  (9, 4669.6145139872415),
#  (10, 4223.283062046857),
#  (11, 3858.1630284505572),
#  (12, 3553.951547133667),
#  (13, 3296.5927867376095),
#  (14, 3076.0468667870587),
#  (15, 2884.9512073963065),
#  (16, 2717.783872835775),
#  (17, 2570.3222056045392),
#  (18, 2439.281915812053),
#  (19, 2322.0701423341056),
#  (20, 2216.6125956220544),
#  (21, 2121.2300882808786),
#  (22, 2034.5487391259883),
#  (23, 1955.4336022687369),
#  (24, 1882.9388889305885),
#  (25, 1816.2701360219207),
#  (26, 1754.755105048835),
#  (27, 1697.8211479295903),
#  (28, 1644.977422993269),
#  (29, 1595.8007904270205),
#  (30, 1549.9245286338858),
#  (31, 1507.0292345213984),
#  (32, 1466.835429986092),
#  (33, 1429.0975126735877),
#  (34, 1393.5987742516243),
#  (35, 1360.1472726934585),
#  (36, 1328.5723925140478),
#  (37, 1298.7219628058021),
#  (38, 1270.459830321339),
#  (39, 1243.6638059281458),
#  (40, 1218.2239190950654),
#  (41, 1194.0409278198024),
#  (42, 1171.0250414239486),
#  (43, 1149.0948215626763),
#  (44, 1128.1762330967633),
#  (45, 1108.2018215150363),
#  (46, 1089.1099976495498),
#  (47, 1070.8444137037473),
#  (48, 1053.353417277111),
#  (49, 1036.5895722439575),
#  (50, 1020.5092371267904),
#  (51, 1005.0721930728063),
#  (52, 990.2413147562014),
#  (53, 975.9822785368367),
#  (54, 962.2633030457313),
#  (55, 949.0549180703345),
#  (56, 936.3297582021049),
#  (57, 924.0623782054079),
#  (58, 912.2290874861958),
#  (59, 900.8078013943964),
#  (60, 889.7779073960712),
#  (61, 879.1201444089832),
#  (62, 868.8164938153759),
#  (63, 858.8500808545032),
#  (64, 849.2050852596162),
#  (65, 839.8666601438581),
#  (66, 830.8208582601759),
#  (67, 822.0545648648352),
#  (68, 813.5554365047503),
#  (69, 805.3118451276658),
#  (70, 797.3128269829033),
#  (71, 789.5480358403654),
#  (72, 782.007700107962),
#  (73, 774.6825834736438),
#  (74, 767.5639487386284),
#  (75, 760.6435245439786),
#  (76, 753.9134747240362),
#  (77, 747.3663700479087),
#  (78, 740.9951621346962),
#  (79, 734.7931593498454),
#  (80, 728.754004509288),
#  (81, 722.8716542351284),
#  (82, 717.140359821899),
#  (83, 711.5546494859848),
#  (84, 706.1093118829532),
#  (85, 700.7993807883707),
#  (86, 695.6201208474096),
#  (87, 690.5670143072426),
#  (88, 685.6357486540566),
#  (89, 680.8222050835283),
#  (90, 676.1224477399442),
#  (91, 671.5327136648308),
#  (92, 667.0494034011176),
#  (93, 662.669072203486),
#  (94, 658.3884218097661),
#  (95, 654.2042927320382),
#  (96, 650.1136570295472),
#  (97, 646.1136115286562),
#  (98, 642.2013714579097),
#  (99, 638.3742644688554),
#  (100, 634.6297250156208),
#  (101, 630.9652890683803),
#  (102, 627.3785891377981),
#  (103, 623.8673495893141),
#  (104, 620.429382227763),
#  (105, 617.0625821343043),
#  (106, 613.7649237390011),
#  (107, 610.5344571136316),
#  (108, 607.369304470459),
#  (109, 604.2676568537324),
#  (110, 601.2277710116547),
#  (111, 598.2479664374354),
#  (112, 595.3266225688625),
#  (113, 592.4621761365714),
#  (114, 589.6531186518819),
#  (115, 586.897994025706),
#  (116, 584.1953963106192),
#  (117, 581.543967558725),
#  (118, 578.942395788443),
#  (119, 576.3894130538157),
#  (120, 573.8837936103497),
#  (121, 571.4243521718108),
#  (122, 569.0099422527514),
#  (123, 566.6394545918924),
#  (124, 564.3118156517941),
#  (125, 562.025986190545),
#  (126, 559.7809599014677),
#  (127, 557.57576211709),
#  (128, 555.4094485738706),
#  (129, 553.2811042343803),
#  (130, 551.1898421638446),
#  (131, 549.1348024581436),
#  (132, 547.1151512205413),
#  (133, 545.1300795845772),
#  (134, 543.1788027807103),
#  (135, 541.2605592444471),
#  (136, 539.374609763816),
#  (137, 537.5202366641818),
#  (138, 535.6967430285008),
#  (139, 533.903451951237),
#  (140, 532.1397058242524),
#  (141, 530.4048656530853),
#  (142, 528.6983104021199),
#  (143, 527.0194363672302),
#  (144, 525.3676565745651),
#  (145, 523.7424002042101),
#  (146, 522.1431120375363),
#  (147, 520.5692519271049),
#  (148, 519.0202942880629),
#  (149, 517.4957276100195),
#  (150, 515.9950539884466),
#  (151, 514.5177886747006),
#  (152, 513.0634596438045),
#  (153, 511.6316071791807),
#  (154, 510.2217834735624),
#  (155, 508.83355224535273),
#  (156, 507.46648836974003),
#  (157, 506.12017752390926),
#  (158, 504.7942158457263),
#  (159, 503.4882096053016),
#  (160, 502.20177488886964),
#  (161, 500.93453729444815),
#  (162, 499.68613163876967),
#  (163, 498.45620167499897),
#  (164, 497.24439982077826),
#  (165, 496.05038689615986),
#  (166, 494.8738318710114),
#  (167, 493.71441162149483),
#  (168, 492.57181069524137),
#  (169, 491.4457210848638),
#  (170, 490.33584200946007),
#  (171, 489.2418797037836),
#  (172, 488.16354721476597),
#  (173, 487.10056420509676),
#  (174, 486.05265676357465),
#  (175, 485.01955722195976),
#  (176, 484.0010039780687),
#  (177, 482.9967413248651),
#  (178, 482.00651928531016),
#  (179, 481.0300934527471),
#  (180, 480.06722483660576),
#  (181, 479.11767971321984),
#  (182, 478.1812294815615),
#  (183, 477.25765052370446),
#  (184, 476.3467240698357),
#  (185, 475.44823606764396),
#  (186, 474.5619770559201),
#  (187, 473.68774204221165),
#  (188, 472.82533038438027),
#  (189, 471.97454567591825),
#  (190, 471.1351956348847),
#  (191, 470.3070919963294),
#  (192, 469.49005040807685),
#  (193, 468.6838903297485),
#  (194, 467.88843493490623),
#  (195, 467.103511016206),
#  (196, 466.3289488934524),
#  (197, 465.5645823244524),
#  (198, 464.810248418569),
#  (199, 464.0657875528794),
#  (200, 463.3310432908466),
#  (201, 462.6058623034174),
#  (202, 461.8900942924623),
#  (203, 461.183591916476),
#  (204, 460.4862107184621),
#  (205, 459.79780905592634),
#  (206, 459.1182480329075),
#  (207, 458.44739143397595),
#  (208, 457.7851056601353),
#  (209, 457.1312596665615),
#  (210, 456.48572490211933),
#  (211, 455.8483752505975),
#  (212, 455.219086973604),
#  (213, 454.5977386550694),
#  (214, 453.9842111473034),
#  (215, 453.3783875185552),
#  (216, 452.7801530020292),
#  (217, 452.18939494630735),
#  (218, 451.60600276713564),
#  (219, 451.02986790052836),
#  (220, 450.4608837571501),
#  (221, 449.8989456779343),
#  (222, 449.3439508908993),
#  (223, 448.7957984691245),
#  (224, 448.25438928985005),
#  (225, 447.71962599466553),
#  (226, 447.1914129507538),
#  (227, 446.6696562131566),
#  (228, 446.1542634880323),
#  (229, 445.64514409687365),
#  (230, 445.1422089416573),
#  (231, 444.64537047089647),
#  (232, 444.15454264657006),
#  (233, 443.6696409119009),
#  (234, 443.19058215995875),
#  (235, 442.7172847030627),
#  (236, 442.24966824295956),
#  (237, 441.78765384175534),
#  (238, 441.33116389357804),
#  (239, 440.88012209694904),
#  (240, 440.4344534278443),
#  (241, 439.99408411342324),
#  (242, 439.55894160640804),
#  (243, 439.128954560093),
#  (244, 438.7040528039669),
#  (245, 438.2841673199299),
#  (246, 437.86923021908945),
#  (247, 437.4591747191169),
#  (248, 437.05393512215113),
#  (249, 436.6534467932318),
#  (250, 436.257646139249),
#  (251, 435.8664705883936),
#  (252, 435.47985857009553),
#  (253, 435.0977494954355),
#  (254, 434.72008373801793),
#  (255, 434.3468026152916),
#  (256, 433.97784837030684),
#  (257, 433.6131641538962),
#  (258, 433.2526940072679),
#  (259, 432.89638284500063),
#  (260, 432.544176438429),
#  (261, 432.19602139940895),
#  (262, 431.8518651644533),
#  (263, 431.51165597922704),
#  (264, 431.17534288339374),
#  (265, 430.84287569580255),
#  (266, 430.51420500000813),
#  (267, 430.189282130114),
#  (268, 429.8680591569305),
#  (269, 429.55048887444065),
#  (270, 429.2365247865642),
#  (271, 428.92612109421333),
#  (272, 428.61923268263195),
#  (273, 428.31581510901174),
#  (274, 428.0158245903773),
#  (275, 427.719217991734),
#  (276, 427.4259528144719),
#  (277, 427.13598718501896),
#  (278, 426.8492798437374),
#  (279, 426.5657901340574),
#  (280, 426.28547799184133),
#  (281, 426.00830393497444),
#  (282, 425.734229053174),
#  (283, 425.4632149980141),
#  (284, 425.19522397315876),
#  (285, 424.930218724799),
#  (286, 424.6681625322894),
#  (287, 424.4090191989782),
#  (288, 424.15275304322745),
#  (289, 423.89932888961704),
#  (290, 423.6487120603301),
#  (291, 423.40086836671384),
#  (292, 423.1557641010122),
#  (293, 422.9133660282668),
#  (294, 422.6736413783806),
#  (295, 422.43655783834237),
#  (296, 422.2020835446068),
#  (297, 421.97018707562694),
#  (298, 421.74083744453566),
#  (299, 421.5140040919723),
#  (300, 421.2896568790515),
#  (301, 421.0677660804703),
#  (302, 420.84830237775105),
#  (303, 420.6312368526166),
#  (304, 420.41654098049463),
#  (305, 420.2041866241484),
#  (306, 419.99414602743093),
#  (307, 419.7863918091596),
#  (308, 419.58089695710936),
#  (309, 419.37763482212006),
#  (310, 419.1765791123174),
#  (311, 418.97770388744385),
#  (312, 418.7809835532961),
#  (313, 418.5863928562697),
#  (314, 418.39390687800477),
#  (315, 418.2035010301334),
#  (316, 418.01515104912517),
#  (317, 417.8288329912287),
#  (318, 417.6445232275078),
#  (319, 417.4621984389691),
#  (320, 417.28183561178025),
#  (321, 417.1034120325758),
#  (322, 416.92690528384963),
#  (323, 416.75229323943154),
#  (324, 416.5795540600463),
#  (325, 416.4086661889534),
#  (326, 416.2396083476664),
#  (327, 416.0723595317484),
#  (328, 415.9068990066848),
#  (329, 415.74320630382863),
#  (330, 415.5812612164193),
#  (331, 415.42104379567235),
#  (332, 415.262534346938),
#  (333, 415.1057134259288),
#  (334, 414.9505618350128),
#  (335, 414.7970606195728),
#  (336, 414.6451910644294),
#  (337, 414.494934690326),
#  (338, 414.34627325047586),
#  (339, 414.1991887271688),
#  (340, 414.0536633284367),
#  (341, 413.9096794847768),
#  (342, 413.76721984593115),
#  (343, 413.62626727772164),
#  (344, 413.486804858939),
#  (345, 413.34881587828494),
#  (346, 413.2122838313664),
#  (347, 413.07719241774043),
#  (348, 412.94352553800974),
#  (349, 412.8112672909662),
#  (350, 412.6804019707833),
#  (351, 412.55091406425487),
#  (352, 412.4227882480805),
#  (353, 412.29600938619603),
#  (354, 412.17056252714787),
#  (355, 412.0464329015113),
#  (356, 411.9236059193515),
#  (357, 411.8020671677257),
#  (358, 411.6818024082269),
#  (359, 411.5627975745674),
#  (360, 411.4450387702021),
#  (361, 411.3285122659899),
#  (362, 411.21320449789357),
#  (363, 411.09910206471653),
#  (364, 410.98619172587604),
#  (365, 410.8744603992124),
#  (366, 410.76389515883295),
#  (367, 410.65448323299074),
#  (368, 410.5462120019971),
#  (369, 410.439068996167),
#  (370, 410.3330418937973),
#  (371, 410.2281185191767),
#  (372, 410.12428684062724),
#  (373, 410.0215349685763),
#  (374, 409.91985115365924),
#  (375, 409.819223784851),
#  (376, 409.71964138762735),
#  (377, 409.6210926221548),
#  (378, 409.52356628150744),
#  (379, 409.4270512899134),
#  (380, 409.3315367010258),
#  (381, 409.2370116962223),
#  (382, 409.14346558292965),
#  (383, 409.05088779297415),
#  (384, 408.9592678809571),
#  (385, 408.8685955226552),
#  (386, 408.77886051344467),
#  (387, 408.69005276674983),
#  (388, 408.60216231251457),
#  (389, 408.51517929569707),
#  (390, 408.42909397478684),
#  (391, 408.3438967203441),
#  (392, 408.25957801356105),
#  (393, 408.1761284448441),
#  (394, 408.0935387124178),
#  (395, 408.0117996209486),
#  (396, 407.9309020801897),
#  (397, 407.85083710364535),
#  (398, 407.77159580725487),
#  (399, 407.69316940809597),
#  (400, 407.61554922310717),
#  (401, 407.5387266678284),
#  (402, 407.46269325516045),
#  (403, 407.38744059414165),
#  (404, 407.3129603887432),
#  (405, 407.2392444366812),
#  (406, 407.16628462824553),
#  (407, 407.09407294514665),
#  (408, 407.0226014593774),
#  (409, 406.9518623320925),
#  (410, 406.88184781250294),
#  (411, 406.8125502367865),
#  (412, 406.7439620270137),
#  (413, 406.67607569008925),
#  (414, 406.60888381670753),
#  (415, 406.5423790803236),
#  (416, 406.47655423613855),
#  (417, 406.41140212009856),
#  (418, 406.3469156479084),
#  (419, 406.2830878140588),
#  (420, 406.21991169086635),
#  (421, 406.15738042752844),
#  (422, 406.09548724918943),
#  (423, 406.03422545602103),
#  (424, 405.9735884223149),
#  (425, 405.9135695955872),
#  (426, 405.8541624956967),
#  (427, 405.7953607139734),
#  (428, 405.7371579123605),
#  (429, 405.6795478225666),
#  (430, 405.6225242452309),
#  (431, 405.5660810490987),
#  (432, 405.5102121702082),
#  (433, 405.4549116110887),
#  (434, 405.40017343996897),
#  (435, 405.34599178999713),
#  (436, 405.29236085847),
#  (437, 405.23927490607326),
#  (438, 405.186728256132),
#  (439, 405.1347152938708),
#  (440, 405.0832304656835),
#  (441, 405.0322682784138),
#  (442, 404.9818232986435),
#  (443, 404.931890151992),
#  (444, 404.8824635224237),
#  (445, 404.8335381515653),
#  (446, 404.78510883803176),
#  (447, 404.73717043676106),
#  (448, 404.6897178583576),
#  (449, 404.6427460684444),
#  (450, 404.59625008702363),
#  (451, 404.5502249878453),
#  (452, 404.5046658977842),
#  (453, 404.45956799622513),
#  (454, 404.4149265144559),
#  (455, 404.3707367350677),
#  (456, 404.32699399136436),
#  (457, 404.28369366677765),
#  (458, 404.2408311942915),
#  (459, 404.1984020558727),
#  (460, 404.15640178190887),
#  (461, 404.1148259506545),
#  (462, 404.07367018768264),
#  (463, 404.0329301653446),
#  (464, 403.9926016022363),
#  (465, 403.9526802626708),
#  (466, 403.9131619561585),
#  (467, 403.8740425368928),
#  (468, 403.83531790324287),
#  (469, 403.79698399725277),
#  (470, 403.75903680414655),
#  (471, 403.72147235183974),
#  (472, 403.68428671045695),
#  (473, 403.64747599185534),
#  (474, 403.61103634915406),
#  (475, 403.5749639762697),
#  (476, 403.53925510745734),
#  (477, 403.5039060168571),
#  (478, 403.46891301804675),
#  (479, 403.43427246359937),
#  (480, 403.3999807446467),
#  (481, 403.3660342904479),
#  (482, 403.33242956796335),
#  (483, 403.29916308143396),
#  (484, 403.2662313719654),
#  (485, 403.2336310171174),
#  (486, 403.2013586304983),
#  (487, 403.16941086136427),
#  (488, 403.13778439422356),
#  (489, 403.1064759484453),
#  (490, 403.0754822778734),
#  (491, 403.04480017044483),
#  (492, 403.0144264478127),
#  (493, 402.98435796497347),
#  (494, 402.95459160989935),
#  (495, 402.9251243031745),
#  (496, 402.89595299763585),
#  (497, 402.86707467801796),
#  (498, 402.8384863606027),
#  (499, 402.81018509287253),
#  (500, 402.7821679531682),
#  (501, 402.7544320503502),
#  (502, 402.72697452346483),
#  (503, 402.69979254141373),
#  (504, 402.6728833026274),
#  (505, 402.64624403474255),
#  (506, 402.6198719942838),
#  (507, 402.5937644663482),
#  (508, 402.5679187642942),
#  (509, 402.5423322294339),
#  (510, 402.5170022307293),
#  (511, 402.49192616449153),
#  (512, 402.4671014540841),
#  (513, 402.4425255496294),
#  (514, 402.4181959277188),
#  (515, 402.39411009112575),
#  (516, 402.3702655685226),
#  (517, 402.3466599142007),
#  (518, 402.32329070779343),
#  (519, 402.3001555540028),
#  (520, 402.2772520823289),
#  (521, 402.2545779468028),
#  (522, 402.23213082572215),
#  (523, 402.20990842139054),
#  (524, 402.1879084598587),
#  (525, 402.1661286906698),
#  (526, 402.1445668866072),
#  (527, 402.1232208434449),
#  (528, 402.10208837970134),
#  (529, 402.08116733639554),
#  (530, 402.06045557680636),
#  (531, 402.0399509862344),
#  (532, 402.0196514717664),
#  (533, 401.99955496204296),
#  (534, 401.9796594070279),
#  (535, 401.95996277778136),
#  (536, 401.94046306623443),
#  (537, 401.92115828496736),
#  (538, 401.90204646698925),
#  (539, 401.88312566552105),
#  (540, 401.8643939537806),
#  (541, 401.8458494247703),
#  (542, 401.82749019106666),
#  (543, 401.8093143846133),
#  (544, 401.791320156515),
#  (545, 401.773505676835),
#  (546, 401.7558691343941),
#  (547, 401.73840873657224),
#  (548, 401.72112270911225),
#  (549, 401.70400929592563),
#  (550, 401.68706675890064),
#  (551, 401.67029337771265),
#  (552, 401.6536874496364),
#  (553, 401.63724728936046),
#  (554, 401.6209712288036),
#  (555, 401.6048576169337),
#  (556, 401.58890481958775),
#  (557, 401.57311121929484),
#  (558, 401.5574752151005),
#  (559, 401.54199522239304),
#  (560, 401.5266696727322),
#  (561, 401.51149701367916),
#  (562, 401.49647570862874),
#  (563, 401.48160423664353),
#  (564, 401.4668810922896),
#  (565, 401.45230478547415),
#  (566, 401.4378738412848),
#  (567, 401.42358679983096),
#  (568, 401.40944221608675),
#  (569, 401.3954386597355),
#  (570, 401.3815747150161),
#  (571, 401.36784898057124),
#  (572, 401.3542600692969),
#  (573, 401.34080660819376),
#  (574, 401.32748723822),
#  (575, 401.31430061414625),
#  (576, 401.30124540441125),
#  (577, 401.28832029098004),
#  (578, 401.2755239692027),
#  (579, 401.2628551476757),
#  (580, 401.25031254810375),
#  (581, 401.2378949051638),
#  (582, 401.2256009663703),
#  (583, 401.2134294919419),
#  (584, 401.20137925466975),
#  (585, 401.18944903978684),
#  (586, 401.1776376448393),
#  (587, 401.16594387955865),
#  (588, 401.1543665657355),
#  (589, 401.1429045370949),
#  (590, 401.13155663917274),
#  (591, 401.12032172919356),
#  (592, 401.1091986759496),
#  (593, 401.0981863596814),
#  (594, 401.08728367195937),
#  (595, 401.0764895155669),
#  (596, 401.0658028043844),
#  (597, 401.05522246327513),
#  (598, 401.0447474279716),
#  (599, 401.03437664496346),
#  (600, 401.02410907138693),
#  (601, 401.0139436749149),
#  (602, 401.00387943364836),
#  (603, 400.9939153360092),
#  (604, 400.98405038063373),
#  (605, 400.97428357626796),
#  (606, 400.9646139416633),
#  (607, 400.9550405054739),
#  (608, 400.9455623061548),
#  (609, 400.93617839186123),
#  (610, 400.926887820349),
#  (611, 400.91768965887604),
#  (612, 400.9085829841048),
#  (613, 400.8995668820057),
#  (614, 400.89064044776177),
#  (615, 400.8818027856743),
#  (616, 400.8730530090693),
#  (617, 400.8643902402047),
#  (618, 400.8558136101796),
#  (619, 400.8473222588432),
#  (620, 400.83891533470523),
#  (621, 400.8305919948477),
#  (622, 400.82235140483704),
#  (623, 400.8141927386371),
#  (624, 400.8061151785237),
#  (625, 400.7981179149996),
#  (626, 400.79020014671016),
#  (627, 400.78236108036054),
#  (628, 400.77459993063326),
#  (629, 400.7669159201067),
#  (630, 400.7593082791748),
#  (631, 400.75177624596694),
#  (632, 400.7443190662694),
#  (633, 400.73693599344716),
#  (634, 400.72962628836666),
#  (635, 400.7223892193193),
#  (636, 400.7152240619461),
#  (637, 400.7081300991623),
#  (638, 400.70110662108397),
#  (639, 400.69415292495415),
#  (640, 400.6872683150707),
#  (641, 400.68045210271424),
#  (642, 400.6737036060776),
#  (643, 400.66702215019495),
#  (644, 400.66040706687266),
#  (645, 400.65385769462046),
#  (646, 400.647373378583),
#  (647, 400.6409534704729),
#  (648, 400.6345973285039),
#  (649, 400.6283043173246),
#  (650, 400.6220738079536),
#  (651, 400.61590517771447),
#  (652, 400.60979781017204),
#  (653, 400.60375109506896),
#  (654, 400.59776442826313),
#  (655, 400.5918372116657),
#  (656, 400.58596885317957),
#  (657, 400.58015876663904),
#  (658, 400.5744063717492),
#  (659, 400.56871109402704),
#  (660, 400.5630723647421),
#  (661, 400.5574896208585),
#  (662, 400.55196230497734),
#  (663, 400.54648986527945),
#  (664, 400.541071755469),
#  (665, 400.5357074347177),
#  (666, 400.53039636760974),
#  (667, 400.5251380240864),
#  (668, 400.51993187939246),
#  (669, 400.5147774140225),
#  (670, 400.5096741136678),
#  (671, 400.5046214691637),
#  (672, 400.4996189764377),
#  (673, 400.4946661364584),
#  (674, 400.48976245518406),
#  (675, 400.48490744351244),
#  (676, 400.4801006172311),
#  (677, 400.4753414969677),
#  (678, 400.47062960814173),
#  (679, 400.46596448091555),
#  (680, 400.46134565014694),
#  (681, 400.4567726553416),
#  (682, 400.45224504060633),
#  (683, 400.4477623546027),
#  (684, 400.44332415050104),
#  (685, 400.43892998593515),
#  (686, 400.4345794229571),
#  (687, 400.4302720279929),
#  (688, 400.4260073717985),
#  (689, 400.421785029416),
#  (690, 400.4176045801307),
#  (691, 400.4134656074282),
#  (692, 400.4093676989521),
#  (693, 400.4053104464623),
#  (694, 400.4012934457937),
#  (695, 400.39731629681495),
#  (696, 400.3933786033878),
#  (697, 400.38947997332735),
#  (698, 400.3856200183619),
#  (699, 400.38179835409375),
#  (700, 400.37801459996035),
#  (701, 400.3742683791956),
#  (702, 400.37055931879183),
#  (703, 400.36688704946175),
#  (704, 400.3632512056017),
#  (705, 400.35965142525384),
#  (706, 400.35608735007),
#  (707, 400.35255862527566),
#  (708, 400.3490648996333),
#  (709, 400.34560582540763),
#  (710, 400.3421810583302),
#  (711, 400.33879025756426),
#  (712, 400.33543308567107),
#  (713, 400.3321092085749),
#  (714, 400.32881829553),
#  (715, 400.3255600190869),
#  (716, 400.3223340550593),
#  (717, 400.3191400824914),
#  (718, 400.3159777836258),
#  (719, 400.3128468438708),
#  (720, 400.30974695176917),
#  (721, 400.30667779896663),
#  (722, 400.30363908018074),
#  (723, 400.3006304931699),
#  (724, 400.29765173870317),
#  (725, 400.2947025205299),
#  (726, 400.2917825453501),
#  (727, 400.28889152278464),
#  (728, 400.2860291653462),
#  (729, 400.28319518841005),
#  (730, 400.28038931018557),
#  (731, 400.27761125168803),
#  (732, 400.2748607367101),
#  (733, 400.27213749179435),
#  (734, 400.2694412462057),
#  (735, 400.26677173190393),
#  (736, 400.26412868351713),
#  (737, 400.26151183831456),
#  (738, 400.25892093618046),
#  (739, 400.25635571958804),
#  (740, 400.25381593357315),
#  (741, 400.25130132570905),
#  (742, 400.2488116460808),
#  (743, 400.2463466472604),
#  (744, 400.2439060842814),
#  (745, 400.24148971461494),
#  (746, 400.23909729814505),
#  (747, 400.23672859714446),
#  (748, 400.2343833762507),
#  (749, 400.2320614024429),
#  (750, 400.2297624450179),
#  (751, 400.2274862755672),
#  (752, 400.2252326679541),
#  (753, 400.22300139829116),
#  (754, 400.2207922449175),
#  (755, 400.21860498837657),
#  (756, 400.2164394113943),
#  (757, 400.214295298857),
#  (758, 400.21217243779023),
#  (759, 400.210070617337),
#  (760, 400.20798962873687),
#  (761, 400.20592926530503),
#  (762, 400.20388932241144),
#  (763, 400.2018695974605),
#  (764, 400.1998698898704),
#  (765, 400.19789000105357),
#  (766, 400.1959297343962),
#  (767, 400.193988895239),
#  (768, 400.19206729085744),
#  (769, 400.19016473044235),
#  (770, 400.1882810250813),
#  (771, 400.18641598773905),
#  (772, 400.1845694332394),
#  (773, 400.18274117824603),
#  (774, 400.1809310412448),
#  (775, 400.1791388425251),
#  (776, 400.1773644041622),
#  (777, 400.1756075499989),
#  (778, 400.17386810562886),
#  (779, 400.17214589837806),
#  (780, 400.1704407572882),
#  (781, 400.16875251309955),
#  (782, 400.1670809982338),
#  (783, 400.16542604677727),
#  (784, 400.1637874944647),
#  (785, 400.1621651786624),
#  (786, 400.16055893835215),
#  (787, 400.1589686141152),
#  (788, 400.1573940481162),
#  (789, 400.1558350840874),
#  (790, 400.15429156731335),
#  (791, 400.15276334461475),
#  (792, 400.15125026433407),
#  (793, 400.14975217631945),
#  (794, 400.1482689319105),
#  (795, 400.1468003839228),
#  (796, 400.1453463866339),
#  (797, 400.14390679576786),
#  (798, 400.1424814684818),
#  (799, 400.1410702633508),
#  (800, 400.13967304035447),
#  (801, 400.1382896608624),
#  (802, 400.13691998762073),
#  (803, 400.1355638847382),
#  (804, 400.13422121767275),
#  (805, 400.1328918532179),
#  (806, 400.1315756594897),
#  (807, 400.1302725059133),
#  (808, 400.12898226321016),
#  (809, 400.1277048033849),
#  (810, 400.1264399997129),
#  (811, 400.12518772672723),
#  (812, 400.12394786020644),
#  (813, 400.12272027716193),
#  (814, 400.1215048558259),
#  (815, 400.12030147563917),
#  (816, 400.119110017239),
#  (817, 400.11793036244734),
#  (818, 400.116762394259),
#  (819, 400.11560599682986),
#  (820, 400.1144610554656),
#  (821, 400.11332745661),
#  (822, 400.11220508783373),
#  (823, 400.1110938378232),
#  (824, 400.10999359636924),
#  (825, 400.1089042543564),
#  (826, 400.1078257037519),
#  (827, 400.10675783759496),
#  (828, 400.1057005499861),
#  (829, 400.1046537360764),
#  (830, 400.1036172920574),
#  (831, 400.1025911151505),
#  (832, 400.10157510359704),
#  (833, 400.1005691566475),
#  (834, 400.09957317455223),
#  (835, 400.098587058551),
#  (836, 400.0976107108636),
#  (837, 400.09664403467946),
#  (838, 400.0956869341487),
#  (839, 400.09473931437213),
#  (840, 400.0938010813919),
#  (841, 400.09287214218244),
#  (842, 400.0919524046406),
#  (843, 400.0910417775771),
#  (844, 400.090140170707),
#  (845, 400.089247494641),
#  (846, 400.0883636608763),
#  (847, 400.08748858178814),
#  (848, 400.08662217062067),
#  (849, 400.0857643414786),
#  (850, 400.0849150093184),
#  (851, 400.0840740899402),
#  (852, 400.08324149997907),
#  (853, 400.0824171568969),
#  (854, 400.08160097897417),
#  (855, 400.08079288530166),
#  (856, 400.07999279577274),
#  (857, 400.079200631075),
#  (858, 400.07841631268263),
#  (859, 400.07763976284855),
#  (860, 400.07687090459666),
#  (861, 400.07610966171404),
#  (862, 400.07535595874367),
#  (863, 400.07460972097675),
#  (864, 400.07387087444516),
#  (865, 400.07313934591434),
#  (866, 400.0724150628758),
#  (867, 400.07169795354014),
#  (868, 400.0709879468296),
#  (869, 400.0702849723712),
#  (870, 400.06958896048985),
#  (871, 400.0688998422011),
#  (872, 400.0682175492047),
#  (873, 400.0675420138771),
#  (874, 400.06687316926576),
#  (875, 400.06621094908155),
#  (876, 400.06555528769263),
#  (877, 400.064906120118),
#  (878, 400.0642633820206),
#  (879, 400.06362700970146),
#  (880, 400.06299694009283),
#  (881, 400.06237311075245),
#  (882, 400.0617554598569),
#  (883, 400.06114392619565),
#  (884, 400.06053844916505),
#  (885, 400.05993896876214),
#  (886, 400.0593454255787),
#  (887, 400.0587577607957),
#  (888, 400.05817591617676),
#  (889, 400.05759983406307),
#  (890, 400.0570294573672),
#  (891, 400.05646472956767),
#  (892, 400.05590559470335),
#  (893, 400.0553519973675),
#  (894, 400.05480388270286),
#  (895, 400.05426119639577),
#  (896, 400.053723884671),
#  (897, 400.0531918942863),
#  (898, 400.05266517252704),
#  (899, 400.0521436672011),
#  (900, 400.0516273266338),
#  (901, 400.0511160996625),
#  (902, 400.05060993563166),
#  (903, 400.0501087843877),
#  (904, 400.0496125962743),
#  (905, 400.0491213221271),
#  (906, 400.04863491326915),
#  (907, 400.04815332150577),
#  (908, 400.0476764991201),
#  (909, 400.04720439886785),
#  (910, 400.04673697397334),
#  (911, 400.04627417812424),
#  (912, 400.04581596546717),
#  (913, 400.04536229060324),
#  (914, 400.0449131085834),
#  (915, 400.044468374904),
#  (916, 400.04402804550256),
#  (917, 400.0435920767532),
#  (918, 400.04316042546225),
#  (919, 400.0427330488642),
#  (920, 400.0423099046173),
#  (921, 400.0418909507992),
#  (922, 400.04147614590335),
#  (923, 400.04106544883405),
#  (924, 400.04065881890324),
#  (925, 400.0402562158257),
#  (926, 400.0398575997157),
#  (927, 400.0394629310824),
#  (928, 400.03907217082656),
#  (929, 400.0386852802363),
#  (930, 400.03830222098316),
#  (931, 400.03792295511863),
#  (932, 400.0375474450702),
#  (933, 400.0371756536375),
#  (934, 400.036807543989),
#  (935, 400.03644307965794),
#  (936, 400.03608222453886),
#  (937, 400.03572494288414),
#  (938, 400.0353711993003),
#  (939, 400.0350209587445),
#  (940, 400.0346741865212),
#  (941, 400.0343308482786),
#  (942, 400.0339909100051),
#  (943, 400.03365433802634),
#  (944, 400.03332109900134),
#  (945, 400.03299115991956),
#  (946, 400.0326644880976),
#  (947, 400.03234105117576),
#  (948, 400.032020817115),
#  (949, 400.03170375419353),
#  (950, 400.0313898310041),
#  (951, 400.0310790164505),
#  (952, 400.0307712797445),
#  (953, 400.0304665904031),
#  (954, 400.0301649182451),
#  (955, 400.02986623338836),
#  (956, 400.02957050624696),
#  (957, 400.02927770752774),
#  (958, 400.02898780822807),
#  (959, 400.0287007796324),
#  (960, 400.0284165933098),
#  (961, 400.0281352211111),
#  (962, 400.02785663516556),
#  (963, 400.0275808078791),
#  (964, 400.0273077119306),
#  (965, 400.0270373202697),
#  (966, 400.0267696061141),
#  (967, 400.0265045429467),
#  (968, 400.02624210451324),
#  (969, 400.0259822648193),
#  (970, 400.02572499812817),
#  (971, 400.02547027895804),
#  (972, 400.0252180820795),
#  (973, 400.02496838251295),
#  (974, 400.02472115552655),
#  (975, 400.02447637663306),
#  (976, 400.02423402158814),
#  (977, 400.0239940663875),
#  (978, 400.0237564872645),
#  (979, 400.023521260688),
#  (980, 400.0232883633601),
#  (981, 400.0230577722136),
#  (982, 400.0228294644096),
#  (983, 400.0226034173356),
#  (984, 400.0223796086032),
#  (985, 400.0221580160455),
#  (986, 400.0219386177155),
#  (987, 400.0217213918832),
#  (988, 400.0215063170342),
#  (989, 400.021293371867),
#  (990, 400.02108253529116),
#  (991, 400.0208737864251),
#  (992, 400.0206671045941),
#  (993, 400.0204624693283),
#  (994, 400.02025986036057),
#  (995, 400.0200592576244),
#  (996, 400.0198606412521),
#  (997, 400.0196639915729),
#  (998, 400.0194692891107),
#  (999, 400.0192765145824),
#  ...]

# %% [markdown]
# ##### Função que **encontra** o *número de prestações* necessário para pagar o empréstimo, a partir do *Valor de parcela* **desejado**:

# %%
loan.encontrar_numero_parcelas(loan.tabela_comparativa(50000,#valor_vista_do_bem
                                                       10000,#valor_entrada_emprestimo
                                                       juros_mensais=            1.01),
                               1500 #valor da parcela que o cliente pode pagar
                               )
# Out:
# 32

# %% [markdown]
# #### Exemplo:

# %% [markdown]
# ##### Parâmetros de exemplo:

# %%
Vp_exemplo = 1000        # Exemplo de valor da parcela desejado ; float

E_exemplo  = 4000        # Exemplo de valor de entrada ; float

Vv_exemplo = 40000       # Exemplo de valor à vista ; float

Jm_exemplo = 1.02        # Exemplo de juros mensais (1.02 = 2% ao mês) ; float

# %% [markdown]
# ##### Número de prestações, pagando parcelas = Vp_exemplo:

# %%
loan.encontrar_numero_parcelas(loan.tabela_comparativa(Vv_exemplo, 
                                                       E_exemplo, 
                                                       Jm_exemplo), 
                                                       Vp_exemplo)
# Out:
# 65

# %% [markdown]
# ## *Patrimônio* após *t* meses com compra no mês *Tc*:

# %% [markdown]
# ### Parâmetros:

# %% [markdown]
# Mês da compra (a partir de t=0):         Tc
#
# Ganho mensal pela Resolução do problema: Gr
#
# Valor de manutenção do Bem:              Vm
#
# Taxa de preciação do Bem (mensal):       pm

# %% [markdown]
# #### Exemplo:

# %%
Tc_exemplo           = 6                                    # Mês da compra (a partir de t=0) ; int

Gr_exemplo           = 200.00                               # Ganho mensal pela Resolução do problema ; float

Vm_exemplo           = 1500.00                              # Valor de manutenção do Bem ; float

pm_exemplo           = eq.anual_para_mensal(0.90)              # depreciação de 10% ao ano do valor do bem adquirido, ou seja, apreciação negativa de 10% ao ano ; float

Am_preparado_exemplo = Am_exemplo + Vp_exemplo + Vm_exemplo # O parâmetro de *aporte inicial* já contabiliza o valor separado no orçamento para as *parcelas e manutenção* do Bem ; float

# %% [markdown]
# #### Observações:

# %% [markdown]
# Uma compra é feita para resolver um problema. Caso esse **problema tenha um custo real mensal**, esse custo será um **bônus no orçamento** após a compra. Exemplo: uber -> carro; aluguel -> casa própria. Esse bônus sera adicionado ao *aporte inicial* como Gr.
#
# Para comprar algo, é preciso ter o dinheiro necessário. Se uma pessoa está **preparada para comprar** algo, é necessário que ela tenha o orçamento para pagar as parcelas e o custo de manutenção, e é realista assumir que a pessoa terá **separado esse dinheiro no orcamento antes de comprar** o Bem (ganhou um aumento, cortou custos, se mudou pra um lugar mais barato, etc...). Normalmente a pessoa organiza o orçamento em um mês e compra no seguinte, mas, se esperasse uns meses (pesquisando ou esperando ofertas, por exemplo), ela poderia **investir esse dinheiro até realizar, efetivamente, a compra** (no mínimo, guardando o dinheiro separado nas caixinhas do Nubank ou porquinho do Inter, onde renderia com uma taxa do CDB). Por isso, o parâmetro de *aporte inicial* já contabiliza o valor separado no orçamento para as *parcelas e manutenção* do Bem.
#
# O ideal é assumir que uma **pessoa pode tanto comprar o Bem à vista quanto financiado**, isto é, ela **separou o dinheiro no orçamento** para as parcelas do financiamento **e** tem o **dinheiro necessário em conta** para o pagamento à vista. Veremos que a escolha correta nem sempre é o pagamento à vista, a depender dos parâmetros iniciais da pessoa. Obviamente, caso a pessoa não tenha o valor necessário para pagar à vista, a única escolha é empréstimo, mas **esse simulador ainda serve para comparar quais condições de empréstimo são as mais favoráveis, mesmo que o agiota acorde de mal humor**.
#
# O **Bem** tem um valor que pode ser **adicionado ao patrimônio ao final** do *Horizonte*. Porém, o valor de **Bens diferentes oscilam de maneiras diferentes**. Por exemplo, uma **casa pode aumentar** de valor com o tempo, aumentando o patrimônio efetivo do proprietário, já um **carro quase sempre diminui** de valor com o tempo. Isso entra no modelo como uma *taxa de preciação*, que pode ser **positiva (apreciação)** ou **negativa (depreciação)**, que vai diminuir ou aumentar o Bem de valor ao longo do tempo.
#
# O *aporte mensal* continua *aumentando* durante o endividamento.

# %% [markdown]
# ### Funções para Patrimônio com **Empreśtimo**:

# %% [markdown]
# #### **Antes** da compra:

# %% [markdown]
# ##### Calcular o *patrimônio acumulado* a partir da organização do orçamento até o *mês efetivo* da compra, guardando o *aporte preparado*:
#
# OBS: Se aplicar essa função **até o Horizonte**, o resultado equivale a uma realidade em que a houve a *preparação no orçamento*, mas *desistência de compra*, sobrando somente o *aporte extra mensal*. Isso faz uma boa comparação do quanto **realmente** custou o Bem para o seu *patrimônio resultante no final*.

# %%
aporte_mensal_efetivo = Am_exemplo + Vp_exemplo + Vm_exemplo # O aporte mensal efetivo já contabiliza o valor separado no orçamento para as parcelas e manutenção do Bem
print(f"Patrimônio logo antes da compra: {eq.patrimonio_puro(P0_exemplo,
                                                             aporte_mensal_efetivo,
                                                             rm_exemplo,
                                                             mm_exemplo,
                                                             Tc_exemplo-1):.2f}")

print(f"Patrimônio caso se prepare para a compra, mas não compre: {eq.patrimonio_puro(P0_exemplo,
                                                                                      aporte_mensal_efetivo,
                                                                                      rm_exemplo,
                                                                                      mm_exemplo,
                                                                                      Th_exemplo):.2f}")
# Out:
# Patrimônio logo antes da compra: 58747.35
# Patrimônio caso se prepare para a compra, mas não compre: 799012.74

# %% [markdown]
# ##### Função que calcula o *patrimônio por tempo* **antes** da compra:

# %%
eq.patrimonio_antes_por_tempo(P0_exemplo,
                              Am_exemplo,
                              rm_exemplo,
                              mm_exemplo,
                              Tc_exemplo,
                              Vp_exemplo,
                              Vm_exemplo)
# Out:
# [42770.0,
#  45892.33930902484,
#  49050.90789084974,
#  52246.04080790495,
#  55478.075982538765,
#  58747.35422058735]

# %% [markdown]
# #### **Durante** a dívida:

# %% [markdown]
# ##### Função que calcula o *patrimônio enquanto endividado* (**a partir do patrimônio acumulado antes da compra**), investindo menos durante todos os *meses de prestação*:
#
# OBS: meses_simulacao = -1 calcula o patrimonio até quitar o financiamento.
# Qualquer outro valor calculará até o mês desejado, ficando a interpretação do resultado ao leitor.

# %%
eq.patrimonio_durante(P0_exemplo,
                      Am_exemplo,
                      rm_exemplo,
                      mm_exemplo,
                      Tc_exemplo,
                      Vv_exemplo,
                      E_exemplo ,
                      Vp_exemplo,
                      Jm_exemplo,
                      Vm_exemplo,
                      Gr_exemplo,
                      meses = -1,
                      info= True) # info=True para mostrar informações adicionais; info=False para não mostrar
# Out:
# Patrimônio antes de comprar o Bem: R$ 58747.35
# Patrimônio após comprar o Bem: R$ 54747.35
# 138348.51822704822

# %% [markdown]
# ##### Função que calcula a *evolução do patrimônio* **durante** o pagamento da dívida:

# %%
eq.patrimonio_durante_por_tempo(P0_exemplo,
                                Am_exemplo,
                                rm_exemplo,
                                mm_exemplo,
                                Tc_exemplo,
                                Vv_exemplo,
                                E_exemplo ,
                                Vp_exemplo,
                                Jm_exemplo,
                                Vm_exemplo,
                                Gr_exemplo)
# Out:
# [55224.02189126826,
#  56142.995670653,
#  57071.247391060075,
#  58008.858980289326,
#  58955.91305181017,
#  59912.4929103607,
#  60878.682557592816,
#  61854.56669776207,
#  62840.23074346405,
#  63835.76082141662,
#  64841.24377828919,
#  65856.76718657863,
#  66882.41935053296,
#  67918.28931212262,
#  68964.46685705984,
#  70021.04252086676,
#  71088.1075949925,
#  72165.75413297923,
#  73254.0749566785,
#  74353.16366251728,
#  75463.11462781474,
#  76584.02301714983,
#  77715.98478878046,
#  78859.09670111415,
#  80013.45631923106,
#  81179.16202145941,
#  82356.31300600427,
#  83545.00929762938,
#  84745.35175439314,
#  85957.4420744387,
#  87181.38280283907,
#  88417.27733849693,
#  89665.22994110067,
#  90925.34573813595,
#  92197.73073195404,
#  93482.49180689717,
#  94779.7367364812,
#  96089.57419063614,
#  97412.11374300509,
#  98747.46587830207,
#  100095.74199972893,
#  101457.05443645222,
#  102831.51645114034,
#  104219.24224756096,
#  105620.34697824047,
#  107034.94675218423,
#  108463.15864265972,
#  109905.10069504203,
#  111360.89193472269,
#  112830.65237508206,
#  114314.503025526,
#  115812.56589958748,
#  117324.9640230931,
#  118851.82144239561,
#  120393.26323267259,
#  121949.4155062921,
#  123520.40542124573,
#  125106.36118964906,
#  126707.4120863115,
#  128323.6884573742,
#  129955.32172901806,
#  131602.4444162417,
#  133265.19013171003,
#  134943.69359467423,
#  136638.09063996328,
#  138348.51822704822]

# %% [markdown]
# #### **Após** a dívida:

# %% [markdown]
# ##### Função que calcula o *patrimônio* **após** a quitação da dívida (**a partir do patrimônio acumulado antes e durante**), **somando**, agora, o valor da parcela no *aporte de investimento mensal*:

# %%
eq.patrimonio_apos(P0_exemplo,
                      Am_exemplo,
                      rm_exemplo,
                      mm_exemplo,
                      12        , # meses após a quitação para calcular o patrimônio final
                      Vv_exemplo,
                      E_exemplo ,
                      Vp_exemplo,
                      Vm_exemplo,
                      Gr_exemplo,
                      Tc_exemplo,
                      Jm_exemplo)
# Out:
# 173985.7645859207

# %% [markdown]
# OBS: Com essa função é possível saber, diretamente, o **patrimônio total acumulado** durante esse período de *economia -> empréstimo -> quitação*, para **qualquer ponto no futuro**.

# %% [markdown]
# ##### Função que calcula a *evolução do patrimônio* a partir da **quitação** da dívida até o *Horizonte de Investimentos* desejado.

# %%
eq.patrimonio_apos_por_tempo(P0_exemplo,
                            Am_exemplo,
                            rm_exemplo,
                            mm_exemplo,
                            12        , # meses após a quitação para calcular o patrimônio final
                            Vv_exemplo,
                            E_exemplo ,
                            Vp_exemplo,
                            Vm_exemplo,
                            Gr_exemplo,
                            Tc_exemplo,
                            Jm_exemplo)
# Out:
# [139908.8759082175,
#  142591.2437034688,
#  145301.38406611426,
#  148039.5444635972,
#  150805.9744426495,
#  153600.9256463027,
#  156424.6518310388,
#  159277.40888407742,
#  162159.45484080422,
#  165071.04990233874,
#  168012.45645324554,
#  170983.93907938682,
#  173985.7645859207]

# %% [markdown]
# #### Juntando tudo:

# %% [markdown]
# ##### Função de visualização do *patrimônio em função do tempo*, juntando todos os períodos (**antes, durante e após**):

# %%
vis.plotar_patrimonio_total_por_tempo(P0_exemplo,
                                      Am_exemplo,
                                      rm_exemplo,
                                      mm_exemplo,
                                      Th_exemplo,
                                      Vv_exemplo,
                                      E_exemplo ,
                                      Vp_exemplo,
                                      Vm_exemplo,
                                      Gr_exemplo,
                                      Tc_exemplo,
                                      Jm_exemplo)

# %% [markdown]
# ##### Patrimônio total final no *Horizonte*, **incluindo o valor do Bem adquirido**, depreciado ou apreciado, de acordo com o mercado atual:

# %%
eq.patrimonio_total_com_endividamento(P0_exemplo,
                                      Am_exemplo,
                                      rm_exemplo,
                                      mm_exemplo,
                                      Th_exemplo,
                                      Vv_exemplo,
                                      E_exemplo ,
                                      Vp_exemplo,
                                      Vm_exemplo,
                                      Gr_exemplo,
                                      Tc_exemplo,
                                      Jm_exemplo,
                                      pm_exemplo)
# Out:
# 323741.36317425483

# %% [markdown]
# ##### **EXTRA**: Função de patrimônio total, a partir da *fórmula matemática* deduzida:
#
# OBS: Essa fórmula está, **teoricamente**, correta, porém, ao computá-la apresenta **erro de domínio** (ver observações teóricas para detalhes). Sua vantagem é ser **computacionalmente mais leve**, por ser só uma função que aplica só uma fórmula, e, também, **não deve propagar erros ao comparar métodos** de compra.

# %%
eq.patrimonio_com_endividamento_defeito_domínio(P0_exemplo,
                                                Am_exemplo,
                                                rm_exemplo,
                                                mm_exemplo,
                                                Th_exemplo,
                                                Tc_exemplo,
                                                Vp_exemplo,
                                                Vm_exemplo,
                                                E_exemplo ,
                                                Vv_exemplo,
                                                Jm_exemplo,
                                                Gr_exemplo,
                                                pm_exemplo)
# Out:
# 372011.2293962758

# %% [markdown]
# #### Exemplo: Compra de **Carro**

# %% [markdown]
# ##### Patrimônio após *Th_exemplo*:

# %% [markdown]
# Não se organizando; Não comprando:

# %%
eq.patrimonio_puro(P0_exemplo, 
                   Am_exemplo, 
                   rm_exemplo, 
                   mm_exemplo, 
                   Th_exemplo)
# Out:
# 171519.02019712687

# %% [markdown]
# Se organizando; Não comprando:

# %%
eq.patrimonio_puro(P0_exemplo          ,
                   Am_preparado_exemplo,
                   rm_exemplo          ,
                   mm_exemplo          ,
                   Th_exemplo          )
# Out:
# 799012.7405038545

# %% [markdown]
# Se organizando; Comprando; sem defeito:

# %%
eq.patrimonio_total_com_endividamento(P0_exemplo,
                                      Am_exemplo,
                                      rm_exemplo,
                                      mm_exemplo,
                                      Th_exemplo,
                                      Vv_exemplo,
                                      E_exemplo ,
                                      Vp_exemplo,
                                      Vm_exemplo,
                                      Gr_exemplo,
                                      Tc_exemplo,
                                      Jm_exemplo,
                                      pm_exemplo)
# Out:
# 323741.36317425483

# %% [markdown]
# Se organizando; Comprando; com defeito:

# %%
eq.patrimonio_com_endividamento_defeito_domínio(P0_exemplo,
                                                Am_exemplo,
                                                rm_exemplo,
                                                mm_exemplo,
                                                Th_exemplo,
                                                Tc_exemplo,
                                                Vp_exemplo,
                                                Vm_exemplo,
                                                E_exemplo,
                                                Vv_exemplo,
                                                Jm_exemplo,
                                                Gr_exemplo,
                                                pm_exemplo)
# Out:
# 372011.2293962758

# %% [markdown]
# ##### Visualização do patrimônio em função do tempo com endividamento:

# %%
vis.plotar_patrimonio_total_por_tempo(P0_exemplo   ,
                                   Am_exemplo  ,
                                   rm_exemplo  ,
                                   mm_exemplo  ,
                                   Th_exemplo-1,
                                   Vv_exemplo  ,
                                   E_exemplo   ,
                                   Vp_exemplo  ,
                                   Vm_exemplo  ,
                                   Gr_exemplo  ,
                                   Tc_exemplo  ,
                                   Jm_exemplo  )

# %% [markdown]
# ### Funções de **Compra à Vista**:

# %% [markdown]
# #### Função de patrimônio total no Horizonte:

# %%
eq.patrimonio_final_sem_endividamento(P0_exemplo,
                                     Am_exemplo,
                                     rm_exemplo,
                                     mm_exemplo,
                                     Tc_exemplo,
                                     Vv_exemplo,
                                     Vp_exemplo,
                                     Gr_exemplo,
                                     Vm_exemplo,
                                     Th_exemplo,
                                     pm_exemplo)
# Out:
# 388070.3114757908

# %% [markdown]
# #### Função de visualização após compra à vista:

# %%
vis.plotar_patrimonio_a_vista_por_tempo(P0_exemplo,
                                       Am_exemplo,
                                       rm_exemplo,
                                       mm_exemplo,
                                       Th_exemplo,
                                       Vv_exemplo,
                                       Vm_exemplo,
                                       Gr_exemplo,
                                       Tc_exemplo,
                                       Vp_exemplo)

# %% [markdown]
# ## Observações Teóricas:

# %% [markdown]
# ajeitar depois: mm nao pode ser igual a rm

# %% [markdown]
# ### Relações Temporais:

# %% [markdown]
# **0 < Tc < (Tc + np) < Th** , para todos Tc,np e Th pertencentes aos **números naturais positivos**.

# %% [markdown]
# #### Conclusão:

# %% [markdown]
# A simulação, *teóricamente*, independe da relação temporal entre os parâmetros. Isto é, se *Tc > Th*, a simulação deve correr como se a pessoa tivesse mudado de ideia e não comprado o Bem, por exemplo. Simulação necessária para comprovação ou disprovação dessa teoria.

# %% [markdown]
# ### Defeito de Domínio:

# %% [markdown]
# As equações dividem o tempo em **3 períodos**: Antes, Durante e Após a compra. É possível chegar à conclusão, analisando as equações, que há **intersecção entre os períodos**, isto é, o mês de divisa é contabilizado duas vezes. Como pensamos, idealmente, em um *Horizonte* muito grande (10 anos, 120 meses, por exemplo), **dois meses extras não adicionariam erro grande no resultado final**, não tanto quanto as eleições presidenciais adicionariam erro nas previsões econômicas, pelo menos. Também, a efeito de comparação, teóricamente, **não há adição de vantagem** na simulação para **empréstimo ou à vista**, pois a **matemática é cruel e não perdoa ninguém**.
#
# Porém, é de se notar a **diferença entre os casos**, tendo em vista esse erro equacional:

# %% [markdown]
# #### Empréstimo:

# %% [markdown]
# Mês Tc: As equações investem 1 *Aporte Resulante* a mais, que renderá até o *Horizonte*.
#
# Mês (Tc + np): As equações investem mais 1 *Aporte Resulante* a mais, que renderá até o *Horizonte*.
#
# Resultado: 1 *aporte* do Mês *Tc* + 1 *aporte* do Mês *(Tc + np)* adicionais.

# %% [markdown]
# #### À Vista:

# %% [markdown]
# Mês Tc: As equações investem 2 *aportes* desse mês a mais, que renderão até o *horizonte*.
#
# Resultado: 2 *aportes* do mês *Tc* adicionais.

# %% [markdown]
# #### Conclusão:

# %% [markdown]
# Na simulação de **Empréstimo**, o investimento extra de *Tc* rende por *(Th - Tc)* meses e o de *(Tc + np)* rende por *[Th - (Tc + np)]* meses, que é menos tempo. Já na de **À Vista**, os dois investimentos em *Tc* rendem por *(Th - Tc)*. Isso pode ser uma **vantagem equacional** para o modo à vista. Porém, é de se notar que o *aporte* extra do mês *(Tc + np)* é **maior que o aporte do mês *Tc*** e, no fim, a escala de tempo deve tornar essas **diferenças muito pequenas**.
#
# De todo modo, simulações são necessárias para conclusão precisa.

# %% [markdown]
# ### Grandes Horizontes:

# %% [markdown]
# Por vezes, ao simular *tempos de horizonte* **muito grandes**, este simulador calcula valores, *aparentemente*, absurdos.
#
# *Como assim terei **20 milhões** investindo só 500tinho por mês? Tem algum erro nisso, certeza!*
#
# A resposta para tal comentário é que **não há erro**, somente a matemática dos **juros compostos** mostrando seu poder.
#
# *Se fosse fácil assim **qualquer um** fazia!*
#
# A resposta à essa resposta àquela resposta ao comentário é que **sim**, *se fosse fácil qualquer um fazia*. Resultados assim exigem dois ingredientes *preciosíssimos* no mundo: **Tempo e Consistência**.
#
# Pode *começar a investir desde os dois anos de idade*, mas se *perder tanto dinheiro quanto render*, morrerá de velhice no **zero**.
# Analogamente, pode *conseguir rendimentos que dobrem seu dinheiro* a cada dois anos (**o sonho de qualquer investidor!**), mas se morrer de velhice em *10 anos*, só será um milionário caso já tenha *começado com grana alta* no bolso.
